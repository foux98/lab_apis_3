# %% [markdown]
# ![spotify_logo](../img/spotify_logo.png)
#
# # Spotify REST API Challenge
#
# __What to listen?__
#
# Create your own playlist based on the related artists and their most popular tracks using the [Spotify REST API](https://developer.spotify.com/)

# %%
# Imports
import pandas as pd
import requests
from dotenv import dotenv_values
import random
import string
import requests
import webbrowser

# %% [markdown]
# ### Get access!!!
#
# Get your `client_id` and `client_secret` to generate your __token__ access

# %%
# Generate token with a POST request

client_id = "4109b2d9f5014671863bb2df1d1fbdd3"
client_secret = "5cb719fae80c4191a9c0b288f51bfe50"
auth_url = 'https://accounts.spotify.com/api/token'

# %%
auth_response = requests.post(auth_url, {'grant_type': 'client_credentials',
                                         'client_id': client_id,
                                         'client_secret': client_secret}).json()

# %%
access_token = auth_response['access_token']
auth_response
# Out:
# {'access_token': 'BQARSC-wWAARHJ61B6FGvterxOlidlLdWJNOTLKx2K2JbFVxCq5uZQu1WEAFgVVvxBExU9x7SKX2jaViZllSIrpy0CjvMIrFIFX-lbbkPUPL_pvKnw8',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %% [markdown]
# ### Set your main variables!!!
#
# Set the `base_uri` (i.e.: end-point), parameters and `headers` for your __GET__ operations

# %%
# Base end-point construction

base_url = 'https://api.spotify.com/v1/'
resource = 'artists/'

header_info = {'Authorization': 'Bearer {token}'.format(token=access_token)}

# %% [markdown]
# ### Create your new playlist!!!
#
# Use [`/related-artists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-related-artists) and [`/top-tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/get-an-artists-top-tracks) in order to get the data that you need.
#
# __Here you have the different artists to start with:__
#
# - __Option 1:__ 0L8ExT028jH3ddEcZwqJJ5
#
# - __Option 2:__ 4Y7tXHSEejGu1vQ9bwDdXW
#
# - __Option 3:__ 6FBDaR13swtiWwGhX1WQsP
#
# - __Option 4:__ 0kyQwKHCZnKE7kTXkxXjrB
#
# - __Option 5:__ 2d0hyoQ5ynDBnkvAbJKORj
#
# - __Option 6:__ 3bgsNtcf5d5h9jbQbohfBK
#
# - __Option 7:__ 7mWCSSOYqm4E9mB7V4ot6S
#
# - __Option 8:__ 64KEffDW9EtZ1y2vBYgq8T
#
# - __Option 9:__ 4k1ELeJKT1ISyDv8JivPpB
#
# - __Option 10:__ 4Z8W4fKeB5YxbusRsdQVPb
#
# - __Option 11:__ 26dSoYclwsYLMAKD3tpOr4
#
# - __Option 12:__ 7y97mc3bZRFXzT2szRM4L4
#
# - __Option 13:__ 1w5Kfo2jwwIPruYS2UWh56
#
#
# > Remember to check the [Requests](https://requests.readthedocs.io/en/latest/) library docs!!!
#
# ---

# %%
# Here you can complete your endpoint URI

artist = '64KEffDW9EtZ1y2vBYgq8T'

full_endpoint = base_url + resource + artist

full_endpoint
# Out:
# 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T'

# %%
# Start building your playlist!!!

relres = requests.get(full_endpoint + '/related-artists', headers=header_info)
related = relres.json()

# %%
df = pd.json_normalize(related['artists'])

# %%
df.explode('genres').head()
# Out:
#             genres                                               href  \
# 0              pop  https://api.spotify.com/v1/artists/69GGBxA162l...
# 1    electro house  https://api.spotify.com/v1/artists/7vk5e3vY1uw...
# 2              edm  https://api.spotify.com/v1/artists/540vIaP2Jwj...
# 2  electronic trap  https://api.spotify.com/v1/artists/540vIaP2Jwj...
# 2              pop  https://api.spotify.com/v1/artists/540vIaP2Jwj...
#
#                        id                                             images  \
# 0  69GGBxA162lTqCwzJG5jLp  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  7vk5e3vY1uw9plTHJAMwjN  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  540vIaP2JwjQb9dm3aArA4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  540vIaP2JwjQb9dm3aArA4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  540vIaP2JwjQb9dm3aArA4  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                name  popularity    type  \
# 0  The Chainsmokers          80  artist
# 1       Alan Walker          78  artist
# 2          DJ Snake          76  artist
# 2          DJ Snake          76  artist
# 2          DJ Snake          76  artist
#
#                                      uri  \
# 0  spotify:artist:69GGBxA162lTqCwzJG5jLp
# 1  spotify:artist:7vk5e3vY1uw9plTHJAMwjN
# 2  spotify:artist:540vIaP2JwjQb9dm3aArA4
# 2  spotify:artist:540vIaP2JwjQb9dm3aArA4
# 2  spotify:artist:540vIaP2JwjQb9dm3aArA4
#
#                                external_urls.spotify followers.href  \
# 0  https://open.spotify.com/artist/69GGBxA162lTqC...           None
# 1  https://open.spotify.com/artist/7vk5e3vY1uw9pl...           None
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9...           None
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9...           None
# 2  https://open.spotify.com/artist/540vIaP2JwjQb9...           None
#
#    followers.total
# 0         20152771
# 1         38658663
# 2          8621938
# 2          8621938
# 2          8621938

# %% [markdown]
# ---
#
# ### Bonus track!!!
#
# You can publish your own Playlist with [`/playlists`](https://developer.spotify.com/documentation/web-api/reference/#/operations/create-playlist) and [`/tracks`](https://developer.spotify.com/documentation/web-api/reference/#/operations/add-tracks-to-playlist).
#
# ![I quit](https://media.giphy.com/media/gui67fZ3xIneM/giphy.gif)

# %%
# Bonus

new_endpoint= 'https://api.spotify.com/v1/artists/'


argument= '?market=GB'


url = new_endpoint + artist + '/top-tracks' + argument

url
# Out:
# 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T/top-tracks?market=GB'

# %%
requests.get(url, headers=header_info).json()['tracks'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#     'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#     'id': '64KEffDW9EtZ1y2vBYgq8T',
#     'name': 'Marshmello',
#     'type': 'artist',
#     'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oSJ7TBVCWMDMiYjXNiCKE'},
#     'href': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE',
#     'id': '3oSJ7TBVCWMDMiYjXNiCKE',
#     'name': 'Kane Brown',
#     'type': 'artist',
#     'uri': 'spotify:artist:3oSJ7TBVCWMDMiYjXNiCKE'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/5gWV4yp27HCbXJ1YLe8hQM'},
#   'href': 'https://api.spotify.com/v1/albums/5gWV4yp27HCbXJ1YLe8hQM',
#   'id': '5gWV4yp27HCbXJ1YLe8hQM',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27300ac867eff7ed64be10a517c',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0200ac867eff7ed64be10a517c',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485100ac867eff7ed64be10a517c',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Miles On It',
#   'release_date': '2024-05-03',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:5gWV4yp27HCbXJ1YLe8hQM'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/64KEffDW9EtZ1y2vBYgq8T'},
#    'href': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T',
#    'id': '64KEffDW9EtZ1y2vBYgq8T',
#    'name': 'Marshmello',
#    'type': 'artist',
#    'uri': 'spotify:artist:64KEffDW9EtZ1y2vBYgq8T'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3oSJ7TBVCWMDMiYjXNiCKE'},
#    'href': 'https://api.spotify.com/v1/artists/3oSJ7TBVCWMDMiYjXNiCKE',
#    'id': '3oSJ7TBVCWMDMiYjXNiCKE',
#    'name': 'Kane Brown',
#    'type': 'artist',
#    'uri': 'spotify:artist:3oSJ7TBVCWMDMiYjXNiCKE'}],
#  'disc_number': 1,
#  'duration_ms': 168355,
#  'explicit': False,
#  'external_ids': {'isrc': 'QZZVQ2400059'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/4pkb8SbRGeHAvdb87v9rpf'},
#  'href': 'https://api.spotify.com/v1/tracks/4pkb8SbRGeHAvdb87v9rpf',
#  'id': '4pkb8SbRGeHAvdb87v9rpf',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Miles On It',
#  'popularity': 84,
#  'preview_url': 'https://p.scdn.co/mp3-preview/f989c539f2f53126339e1dd7dbd9213f3b1349b2?cid=4109b2d9f5014671863bb2df1d1fbdd3',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:4pkb8SbRGeHAvdb87v9rpf'}

# %%
top_tracks = pd.concat([pd.DataFrame(requests.get(new_endpoint + artista + '/top-tracks' + argument, 
                                                  headers=header_info).json()['tracks'])
                        for artista in df['id']])

# %%
top_tracks.head()
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'single', 'artists': [{'externa...
# 2  {'album_type': 'single', 'artists': [{'externa...
# 3  {'album_type': 'single', 'artists': [{'externa...
# 4  {'album_type': 'single', 'artists': [{'externa...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       247160     False  {'isrc': 'USQX91700278'}
# 1       244960     False  {'isrc': 'USQX91601347'}
# 2       152250      True  {'isrc': 'NLRD52350359'}
# 3       208373     False  {'isrc': 'USQX91600011'}
# 4       175500     False  {'isrc': 'DEE862301476'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6R...
# 1  {'spotify': 'https://open.spotify.com/track/7B...
# 2  {'spotify': 'https://open.spotify.com/track/5Z...
# 3  {'spotify': 'https://open.spotify.com/track/1i...
# 4  {'spotify': 'https://open.spotify.com/track/0O...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6RUKPb4LETWm...  6RUKPb4LETWmmr3iAEQktW
# 1  https://api.spotify.com/v1/tracks/7BKLCZ1jbUBV...  7BKLCZ1jbUBVqRi2FVlTVw
# 2  https://api.spotify.com/v1/tracks/5ZUIPLoTLJZr...  5ZUIPLoTLJZrPQh2kFZEUM
# 3  https://api.spotify.com/v1/tracks/1i1fxkWeaMmK...  1i1fxkWeaMmKEB4T7zqbzK
# 4  https://api.spotify.com/v1/tracks/0OvO2X2Q3i98...  0OvO2X2Q3i98dc5RcgEN3x
#
#    is_local  is_playable                      name  popularity  \
# 0     False         True  Something Just Like This          87
# 1     False         True                    Closer          85
# 2     False         True                  Addicted          83
# 3     False         True         Don't Let Me Down          81
# 4     False         True                    Jungle          78
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/4e117abe76700eb1...             5  track
# 1  https://p.scdn.co/mp3-preview/cfd565c4d3c62177...             1  track
# 2  https://p.scdn.co/mp3-preview/0f6ed1e0061fffcc...             1  track
# 3  https://p.scdn.co/mp3-preview/4db7d84bd5906590...             1  track
# 4  https://p.scdn.co/mp3-preview/8129813342e4d3ad...             1  track
#
#                                     uri
# 0  spotify:track:6RUKPb4LETWmmr3iAEQktW
# 1  spotify:track:7BKLCZ1jbUBVqRi2FVlTVw
# 2  spotify:track:5ZUIPLoTLJZrPQh2kFZEUM
# 3  spotify:track:1i1fxkWeaMmKEB4T7zqbzK
# 4  spotify:track:0OvO2X2Q3i98dc5RcgEN3x

# %% [markdown]
# ---

# %% [markdown]
# You can always try with the [wrapper](https://github.com/plamere/spotipy)!!!
#
# ![I quit](https://media.giphy.com/media/3oFzlXPvXYZ4q8VQOs/giphy.gif)

# %% [markdown]
# ---
